# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('archive\IPL Player Stats - 2016 till 2019.csv')

# %%
data
# Out:
#                  Team         Player Tournament  Matches Batting Innings  \
# 0    Delhi Daredevils      CH Morris   IPL 2016       12               7
# 1    Delhi Daredevils      CH Morris   IPL 2017        9               9
# 2    Delhi Daredevils      CH Morris   IPL 2018        4               4
# 3    Delhi Daredevils      JP Duminy   IPL 2016       10               8
# 4    Delhi Daredevils      Q de Kock   IPL 2016       13              13
# ..                ...            ...        ...      ...             ...
# 626    Delhi Capitals   S Lamichhane   IPL 2019        6               1
# 627    Delhi Capitals      CA Ingram   IPL 2019       12              12
# 628    Delhi Capitals  SE Rutherford   IPL 2019        7               7
# 629    Delhi Capitals       KMA Paul   IPL 2019        8               6
# 630    Delhi Capitals      GH Vihari   IPL 2019        2               2
#
#     Not Out Runds Scored Highest Score Batting Average Balls Faced  ...  \
# ...
